# %% [markdown]
# 참고 : https://www.kaggle.com/code/gcdatkin/food-image-classification

# %% [markdown]
# ## Getting Started

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
image_dir = Path('./imgs_data')

# %% [markdown]
# ## RGBA가 섞여있을수 있으므로 RGB로 변환작업

# %%
for image in os.listdir(path/to/img/dir):
    
    im = Image.open(image)
    # If is png image
    if im.format is 'PNG':
        
    # and is not RGBA
    if im.mode is not 'RGBA':
        im.convert("RGBA").save(f"{image}2.png")

# %% [markdown]
# ## Creating File DataFrame

# %%
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

images = pd.concat([filepaths, labels], axis=1)

category_samples = []
for category in images['Label'].unique():
    category_slice = images.query("Label == @category")
    category_samples.append(category_slice.sample(300, random_state=1))
image_df = pd.concat(category_samples, axis=0).sample(frac=1.0, random_state=1).reset_index(drop=True)

# %%
image_df
# Out:
#                      Filepath Label
# 0    imgs_data\탕수육\탕수육112.jpg   탕수육
# 1     imgs_data\탕수육\탕수육46.jpg   탕수육
# 2    imgs_data\탕수육\탕수육288.jpg   탕수육
# 3    imgs_data\탕수육\탕수육267.jpg   탕수육
# 4      imgs_data\짬뽕\짬뽕140.jpg    짬뽕
# ..                        ...   ...
# 895  imgs_data\탕수육\탕수육149.jpg   탕수육
# 896   imgs_data\탕수육\탕수육94.jpg   탕수육
# 897    imgs_data\짜장면\짜장면2.jpg   짜장면
# 898  imgs_data\짜장면\짜장면245.jpg   짜장면
# 899  imgs_data\짜장면\짜장면247.jpg   짜장면
#
# [900 rows x 2 columns]

# %%
image_df['Label'].value_counts()
# Out:
# 짬뽕     300
# 탕수육    300
# 짜장면    300
# Name: Label, dtype: int64

# %% [markdown]
# ## Train-Test Split

# %%
train_df, test_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
len(train_df), len(test_df)
# Out:
# (720, 180)

# %% [markdown]
# ## Creating Generators

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 576 validated image filenames belonging to 3 classes.
# Found 144 validated image filenames belonging to 3 classes.
# Found 180 validated image filenames belonging to 3 classes.

# %% [markdown]
# ## Modeling

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)


print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_3[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %% [markdown]
# ## Training

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=10,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[41], line 7
#       1 model.compile(
#       2     optimizer='adam',
#       3     loss=tf.keras.losses.categorical_crossentropy,
#       4     metrics=['accuracy']
#       5 )
# ----> 7 history = model.fit(
#       8     train_images,
#       9     validation_data=val_images,
#      10     epochs=10,
#      11     callbacks=[
#      12         tf.keras.callbacks.EarlyStopping(
#      13             monitor='val_loss',
#      14             patience=3,
#      15             restore_best_weights=True
#      16         )
#      17     ]
#      18 )
#
# File ~\miniconda3\envs\gpu\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
# ...

# %% [markdown]
# ## Results

# %%
results = model.evaluate(test_images, verbose=0)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# Test Accuracy: 78.33%

# %%
predictions = np.argmax(model.predict(test_images), axis=1)

cm = confusion_matrix(test_images.labels, predictions)
clr = classification_report(test_images.labels, predictions, target_names=test_images.class_indices, zero_division=0)
# Out:
# 6/6 [==============================] - 4s 527ms/step

# %%
len(train_images), len(test_images), len(predictions)
# Out:
# (18, 6, 180)

# %%
print("Classification Report:\n----------------------\n", clr)
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#          짜장면       0.64      0.87      0.74        45
#           짬뽕       0.84      0.78      0.81        67
#          탕수육       0.88      0.74      0.80        68
#
#     accuracy                           0.78       180
#    macro avg       0.79      0.79      0.78       180
# weighted avg       0.80      0.78      0.79       180

# %%
import matplotlib.pyplot as plt

plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']

plt.figure(figsize=(12,8))

for each in plot_target:
    plt.plot(history.history[each], label=each)
    
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Results Analysis

# %%
test_df_tmp = test_df.copy()
test_df_tmp = test_df_tmp.reset_index(drop=True)
test_df_tmp['pred'] = predictions
test_df_tmp
# Out:
#                     Filepath Label  pred
# 0      imgs_data\피자\피자45.jpg    피자     2
# 1    imgs_data\짜장면\짜장면76.jpg   짜장면     0
# 2      imgs_data\피자\피자73.jpg    피자     2
# 3      imgs_data\치킨\치킨93.jpg    치킨     1
# 4     imgs_data\햄버거\햄버거7.jpg   햄버거     3
# ..                       ...   ...   ...
# 115  imgs_data\햄버거\햄버거53.jpg   햄버거     3
# 116  imgs_data\햄버거\햄버거31.jpg   햄버거     3
# 117    imgs_data\치킨\치킨62.jpg    치킨     1
# 118    imgs_data\치킨\치킨79.jpg    치킨     1
# 119    imgs_data\피자\피자53.jpg    피자     2
#
# [120 rows x 3 columns]

# %%
food_dic = {
    "짜장면": 0,
    "치킨" : 1, 
    "피자" : 2, 
    "햄버거": 3,
}

# %%
test_df_tmp.insert(3, "pred_label", [key  for num_label in test_df_tmp["pred"] for key, value in food_dic.items() if num_label==value])
test_df_tmp
# Out:
#                     Filepath Label  pred pred_label
# 0      imgs_data\피자\피자45.jpg    피자     2         피자
# 1    imgs_data\짜장면\짜장면76.jpg   짜장면     0        짜장면
# 2      imgs_data\피자\피자73.jpg    피자     2         피자
# 3      imgs_data\치킨\치킨93.jpg    치킨     1         치킨
# 4     imgs_data\햄버거\햄버거7.jpg   햄버거     3        햄버거
# ..                       ...   ...   ...        ...
# 115  imgs_data\햄버거\햄버거53.jpg   햄버거     3        햄버거
# 116  imgs_data\햄버거\햄버거31.jpg   햄버거     3        햄버거
# 117    imgs_data\치킨\치킨62.jpg    치킨     1         치킨
# 118    imgs_data\치킨\치킨79.jpg    치킨     1         치킨
# 119    imgs_data\피자\피자53.jpg    피자     2         피자
#
# [120 rows x 4 columns]

# %%
wrong_result = []

for n in range(0,len(test_df_tmp)):
    if test_df_tmp['Label'][n] != test_df_tmp['pred_label'][n]:
        wrong_result.append(n)
        
print("Test Num :", len(predictions))
print("correct / wrong :", (len(predictions)-len(wrong_result)),'/', len(wrong_result))
# Out:
# Test Num : 120
# correct / wrong : 111 / 9

# %%
import platform
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    print("Hangul set complete in your MAC!")
    rc("font", family = "Arial Unicode MS")
    
elif platform.system() == "Windows":
    print("Hangul set complete in your Windows!")
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc("font", family = font_name)

else:
    print("Unknown your system....")
    
plt.rcParams["axes.unicode_minus"] = False
# Out:
# Hangul set complete in your Windows!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def process(filename: str=None) -> None:
    """
    View multiple images stored in files, stacking vertically

    Arguments:
        filename: str - path to filename containing image
    """
    image = mpimg.imread(filename)
    # <something gets done here>
    plt.figure()
    food_name = test_df_tmp['Filepath'][2].split('\\')[1]
    
    plt.title('Real Name : '+str(test_df_tmp['Label'][n]) + ' | Pred Name : '+ str(test_df_tmp['pred_label'][n]))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
from skimage.transform import rescale, resize
from skimage import color
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
import random

samples = random.choices(population=wrong_result, k=8)


for idx, n in enumerate(samples):
    
    img_path = './'+ test_df_tmp['Filepath'][n]
    process(img_path)
