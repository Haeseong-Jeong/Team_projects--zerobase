# %%
# !nvidia-smi
# Out:
# Wed Oct 25 13:46:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.201
#     Uninstalling ultralytics-8.0.201:
#       Successfully uninstalled ultralytics-8.0.201
# ...

# %%
data.yaml

names:
-chicken
-pizza
-burger
-pork_cutlet
-sushi
-salad
-pork_feet
-juck
-bossam
-gimbab
-dduckbokki
-Jajangmyeon
-Jjambbong
-Sweet_and_sour_pork
nc: 15
test : 경로
train : 경로
val : 경로

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.train(data='{data_path}/data.yaml', epochs=30)

# %%
import locale
locale.getpreferredencoding = lambda:"UTF-8"
# !yolo task=detect mode=predict model=/{model_path}/best.pt source={test_image}

# %% [markdown]
# ----

# %% [markdown]
# # 데이터셋 폴더구조 세팅하기

# %%
def create_folder(directory):
    import os

    if not os.path.exists(directory):
        os.mkdir(directory)

# %%
import os
import shutil

#--------- 데이터 저장할 경로 지정
fit_dataset_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code'
create_folder(fit_dataset_dir)


#--------- train,valid,test 폴더로 분리
train_dir = os.path.join(fit_dataset_dir, 'train')
create_folder(train_dir)

validation_dir = os.path.join(fit_dataset_dir, 'validation')
create_folder(validation_dir)

#test_dir = os.path.join(fit_dataset_dir, 'test')
#create_folder(test_dir)

#--------- 각 폴더에 images/ lebels 폴더로 분리
data_table = ['images','labels']

for table in data_table:
    create_folder(os.path.join(train_dir, table))
    create_folder(os.path.join(validation_dir, table))
    #create_folder(os.path.join(test_dir, table))

# %%
import os

# %%
os.listdir('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data')
# Out:
# ['fit_dataset_with_code', '.ipynb_checkpoints', 'images_data', 'labels_data']

# %% [markdown]
# ## 폴더에 이미지, 라벨 데이터 넣기

# %%
cls = 'Jajangmyeon'
cls_label_dir = glob(after_labeling_dir + cls +'*')
valid_ratio = int(len(cls_label_dir)*0.2)

train_set = cls_label_dir[:-valid_ratio]
valid_set = cls_label_dir[-valid_ratio:]

# %%
for train_labels in train_set:
  print(train_labels.split('/')[-1])
# Out:
# Jajangmyeon62.txt
# Jajangmyeon15.txt
# Jajangmyeon31.txt
# Jajangmyeon28.txt
# Jajangmyeon194.txt
# Jajangmyeon128.txt
# Jajangmyeon23.txt
# Jajangmyeon40.txt
# Jajangmyeon162.txt
# Jajangmyeon280.txt
# Jajangmyeon111.txt
# Jajangmyeon217.txt
# Jajangmyeon270.txt
# Jajangmyeon93.txt
# Jajangmyeon20.txt
# Jajangmyeon98.txt
# Jajangmyeon177.txt
# Jajangmyeon248.txt
# Jajangmyeon78.txt
# Jajangmyeon190.txt
# Jajangmyeon116.txt
# Jajangmyeon221.txt
# Jajangmyeon94.txt
# Jajangmyeon159.txt
# Jajangmyeon30.txt
# Jajangmyeon165.txt
# Jajangmyeon213.txt
# Jajangmyeon106.txt
# Jajangmyeon230.txt
# Jajangmyeon206.txt
# Jajangmyeon43.txt
# Jajangmyeon33.txt
# Jajangmyeon176.txt
# Jajangmyeon65.txt
# Jajangmyeon135.txt
# Jajangmyeon87.txt
# Jajangmyeon1.txt
# Jajangmyeon198.txt
# Jajangmyeon27.txt
# Jajangmyeon117.txt
# Jajangmyeon144.txt
# Jajangmyeon158.txt
# Jajangmyeon51.txt
# Jajangmyeon4.txt
# Jajangmyeon107.txt
# Jajangmyeon84.txt
# Jajangmyeon101.txt
# Jajangmyeon147.txt
# ...

# %%
import shutil
from glob import glob

target_class = ['Jajangmyeon', 'Jjambbong', 'Sweet_and_sour_pork']
#data_table = ['train','validation']

origin_img_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/images_data'
after_labeling_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/labels_data/*'
fit_data_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code'

for cls in target_class:
    cls_label_dir = glob(after_labeling_dir + cls +'*')

    valid_ratio = int(len(cls_label_dir)*0.2)

    train_set = cls_label_dir[:-valid_ratio]
    valid_set = cls_label_dir[-valid_ratio:]

    for train_labels in train_set:
        txt_file = train_labels.split('/')[-1]
        destination = fit_data_dir + '/train/labels/' + txt_file
        shutil.copyfile(train_labels, destination)

        origin_img = origin_img_dir + '/' + cls + '/' + txt_file[:-4]+'.jpg'
        destination_img = fit_data_dir + '/train/images/' + txt_file[:-4]+'.jpg'
        shutil.copyfile(origin_img, destination_img)

    for valid_labels in valid_set:
        txt_file = valid_labels.split('/')[-1]
        destination = fit_data_dir + '/validation/labels/' + txt_file
        shutil.copyfile(valid_labels, destination)

        origin_img = origin_img_dir + '/' + cls + '/' + txt_file[:-4]+'.jpg'
        destination_img = fit_data_dir + '/validation/images/' + txt_file[:-4]+'.jpg'
        shutil.copyfile(origin_img, destination_img)

# %%
import shutil
from glob import glob

target_class = ['chicken', 'pizza', 'burger', 'pork_cutlet', 'sandwich', 'sushi', 'salad', 'pork_feet', 'juck', 'bossam', 'gimbab', 'dduckbokki',]
#data_table = ['train','validation']

origin_img_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/images_data'
after_labeling_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/labels_data/*'
fit_data_dir = '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code'

for cls in target_class:
    cls_label_dir = glob(after_labeling_dir + cls +'*')

    valid_ratio = int(len(cls_label_dir)*0.2)

    train_set = cls_label_dir[:-valid_ratio]
    valid_set = cls_label_dir[-valid_ratio:]

    for train_labels in train_set:
        txt_file = train_labels.split('/')[-1]
        destination = fit_data_dir + '/train/labels/' + txt_file
        shutil.copyfile(train_labels, destination)

        origin_img = origin_img_dir + '/' + cls + '/' + txt_file[:-4]+'.jpg'
        destination_img = fit_data_dir + '/train/images/' + txt_file[:-4]+'.jpg'
        shutil.copyfile(origin_img, destination_img)

    for valid_labels in valid_set:
        txt_file = valid_labels.split('/')[-1]
        destination = fit_data_dir + '/validation/labels/' + txt_file
        shutil.copyfile(valid_labels, destination)

        origin_img = origin_img_dir + '/' + cls + '/' + txt_file[:-4]+'.jpg'
        destination_img = fit_data_dir + '/validation/images/' + txt_file[:-4]+'.jpg'
        shutil.copyfile(origin_img, destination_img)

# %% [markdown]
# ## 학습데이터 구조대로 분리 되었나 확인

# %%
train_imgs = os.listdir('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/train/images')
train_labels = os.listdir('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/train/labels')

valid_imgs = os.listdir('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/validation/images')
valid_labels = os.listdir('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/validation/labels')

len(train_imgs), len(train_labels), len(valid_imgs), len(valid_labels)
# Out:
# (1260, 1260, 313, 313)

# %%
import os
train_imgs = os.listdir('../Data/fit_dataset_with_code/train/images/')[:3]
train_labels = os.listdir('../Data/fit_dataset_with_code/train/labels/')[:3]

valid_imgs = os.listdir('../Data/fit_dataset_with_code/validation/images/')[:3]
valid_labels = os.listdir('../Data/fit_dataset_with_code/validation/labels/')[:3]

print(train_imgs)
print(train_labels)

print(valid_imgs)
print(valid_labels)

# %% [markdown]
# # yaml 파일 만들기

# %%
# !pip install PyYAML

# %%
import yaml

data = {'train' : '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/train',
        'val' : '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/validation',
        'names' : ['chicken', 'pizza', 'burger', 'pork_cutlet', 'sandwich', 'sushi', 'salad', 'pork_feet',
                   'juck', 'bossam', 'gimbab', 'dduckbokki', 'Jajangmyeon', 'Jjambbong', 'Sweet_and_sour_pork'],
        'nc' : 15 }

with open('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/yogiyo_data.yaml', 'w') as f:
  yaml.dump(data, f)

with open('/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/yogiyo_data.yaml', 'r') as f:
  yogiyo_yaml = yaml.safe_load(f)
  display(yogiyo_yaml)
# Out:
# {'names': ['chicken',
#   'pizza',
#   'burger',
#   'pork_cutlet',
#   'sandwich',
#   'sushi',
#   'salad',
#   'pork_feet',
#   'juck',
#   'bossam',
#   'gimbab',
#   'dduckbokki',
#   'Jajangmyeon',
#   'Jjambbong',
#   'Sweet_and_sour_pork'],
#  'nc': 15,
#  'train': '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/train',
#  'val': '/content/drive/MyDrive/Colab Notebooks/yogiyo_pj/Data/fit_dataset_with_code/validation'}
